# %%
import pandas as pd

# %%
df=pd.read_csv("D:\Csv files\gdp.csv")

# %%
df.head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %%
df
# Out:
#       Country Name Country Code  Year         Value
# 0       Arab World          ARB  1968  2.576068e+10
# 1       Arab World          ARB  1969  2.843420e+10
# 2       Arab World          ARB  1970  3.138550e+10
# 3       Arab World          ARB  1971  3.642691e+10
# 4       Arab World          ARB  1972  4.331606e+10
# ...            ...          ...   ...           ...
# 11502     Zimbabwe          ZWE  2012  1.424249e+10
# 11503     Zimbabwe          ZWE  2013  1.545177e+10
# 11504     Zimbabwe          ZWE  2014  1.589105e+10
# 11505     Zimbabwe          ZWE  2015  1.630467e+10
# 11506     Zimbabwe          ZWE  2016  1.661996e+10
#
# [11507 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# Country Name    0
# Country Code    0
# Year            0
# Value           0
# dtype: int64

# %%
df["Country Name"].describe()
# Out:
# count                    11507
# unique                     256
# top       Hong Kong SAR, China
# freq                        57
# Name: Country Name, dtype: object

# %%
df["Country Code"].describe()
# Out:
# count     11507
# unique      256
# top         HKG
# freq         57
# Name: Country Code, dtype: object

# %%
df["Year"].describe()
# Out:
# count    11507.000000
# mean      1991.265230
# std         15.886648
# min       1960.000000
# 25%       1978.000000
# 50%       1993.000000
# 75%       2005.000000
# max       2016.000000
# Name: Year, dtype: float64

# %%
df1=df[df["Country Name"]=="Arab World"]

# %%
df1.plot(kind='line',x='Year',y='Value',grid=True,legend=True,xlabel="Years",ylabel="GDP")
# Out:
# <Axes: xlabel='Years', ylabel='GDP'>

# %%
data[0][3]
# Out:
# 25760683041.0857

# %%
data=df.values
gdp1=[0]
for i in range(1,len(data)):
    prev=data[i-1][3]
    cur=data[i][3]
    
    print(data[i][2],round((cur-prev)/prev*100,2))
    gdp1.append(round((cur-prev)/prev*100,2))
# Out:
# 1969 10.38
# 1970 10.38
# 1971 16.06
# 1972 18.91
# 1973 27.02
# 1974 91.11
# 1975 10.64
# 1976 24.51
# 1977 15.51
# 1978 9.71
# 1979 35.46
# 1980 36.01
# 1981 3.08
# 1982 -6.96
# 1983 -6.28
# 1984 1.31
# 1985 -1.31
# 1986 -4.89
# 1987 8.18
# 1988 -1.66
# 1989 4.82
# 1990 38.64
# 1991 -1.59
# 1992 7.14
# 1993 1.14
# 1994 2.31
# 1995 7.43
# 1996 10.4
# 1997 6.06
# 1998 -3.55
# 1999 8.85
# 2000 14.15
# 2001 -1.6
# 2002 0.8
# 2003 12.9
# 2004 17.1
# 2005 22.91
# 2006 18.52
# 2007 16.63
# 2008 26.9
# 2009 -13.58
# 2010 17.48
# 2011 18.58
# 2012 9.58
# 2013 3.59
# 2014 2.36
# 2015 -11.81
# 2016 -2.29
# 1960 -99.92
# 1961 8.23
# 1962 5.52
# 1963 6.21
# 1964 8.03
# 1965 7.68
# 1966 8.46
# 1967 7.34
# 1968 -0.56
# 1969 8.83
# 1970 10.02
# 1971 8.72
# 1972 15.77
# 1973 9.24
# 1974 30.0
# 1975 17.01
# 1976 2.62
# 1977 16.26
# 1978 2.01
# 1979 14.57
# 1980 22.68
# 1981 10.35
# 1982 11.67
# 1983 0.94
# 1984 -5.81
# 1985 -1.67
# 1986 -10.62
# 1987 7.13
# 1988 5.97
# 1989 1.42
# 1990 7.53
# ...

# %%
df.assign(GDP=gdp1)
# Out:
#       Country Name Country Code  Year         Value    GDP
# 0       Arab World          ARB  1968  2.576068e+10   0.00
# 1       Arab World          ARB  1969  2.843420e+10  10.38
# 2       Arab World          ARB  1970  3.138550e+10  10.38
# 3       Arab World          ARB  1971  3.642691e+10  16.06
# 4       Arab World          ARB  1972  4.331606e+10  18.91
# ...            ...          ...   ...           ...    ...
# 11502     Zimbabwe          ZWE  2012  1.424249e+10  17.72
# 11503     Zimbabwe          ZWE  2013  1.545177e+10   8.49
# 11504     Zimbabwe          ZWE  2014  1.589105e+10   2.84
# 11505     Zimbabwe          ZWE  2015  1.630467e+10   2.60
# 11506     Zimbabwe          ZWE  2016  1.661996e+10   1.93
#
# [11507 rows x 5 columns]

# %%
df["Country Name"].unique()
# Out:
# array(['Arab World', 'Caribbean small states',
#        'Central Europe and the Baltics', 'Early-demographic dividend',
#        'East Asia & Pacific',
#        'East Asia & Pacific (excluding high income)',
#        'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (excluding high income)',
#        'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
#        'Fragile and conflict affected situations',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
#        'IDA total', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & the Caribbean (IDA & IBRD countries)',
#        'Least developed countries: UN classification',
#        'Low & middle income', 'Low income', 'Lower middle income',
# ...

# %%
final=[]
for i in df["Country Name"].unique():
    df1=df[df["Country Name"]==i]
    data=df1.values
    gdp1=[0]
    for i in range(1,len(data)):
        prev=data[i-1][3]
        cur=data[i][3]
        gdp1.append(round((cur-prev)/prev*100,2))
    df1=df1.assign(GDP=gdp1)
    final.append(df1)

# %%
df=pd.concat(final,axis=0)

# %%
df
# Out:
#       Country Name Country Code  Year         Value    GDP
# 0       Arab World          ARB  1968  2.576068e+10   0.00
# 1       Arab World          ARB  1969  2.843420e+10  10.38
# 2       Arab World          ARB  1970  3.138550e+10  10.38
# 3       Arab World          ARB  1971  3.642691e+10  16.06
# 4       Arab World          ARB  1972  4.331606e+10  18.91
# ...            ...          ...   ...           ...    ...
# 11502     Zimbabwe          ZWE  2012  1.424249e+10  17.72
# 11503     Zimbabwe          ZWE  2013  1.545177e+10   8.49
# 11504     Zimbabwe          ZWE  2014  1.589105e+10   2.84
# 11505     Zimbabwe          ZWE  2015  1.630467e+10   2.60
# 11506     Zimbabwe          ZWE  2016  1.661996e+10   1.93
#
# [11507 rows x 5 columns]

# %%
df2=df[["Country Name",'GDP']]

# %%
df2.groupby('Country Name').mean()['GDP'].sort_values(ascending=False)
# Out:
# Country Name
# Cayman Islands              108.380000
# Equatorial Guinea            22.312453
# Nauru                        20.650000
# Iraq                         18.075854
# Oman                         17.681154
#                                ...
# Barbados                      3.109259
# San Marino                    2.148333
# American Samoa                1.937333
# Northern Mariana Islands      0.338667
# South Sudan                  -3.166250
# Name: GDP, Length: 256, dtype: float64

# %%
import plotly.express as px
import plotly.offline  as pyo

# %%
df3=df[df["Country Name"]=='World']
fig=px.line(df3,x="Year",y="Value",title="World GDP Analysis")
fig

# %%
df3=df[df["Country Name"]=='India']
fig=px.line(df3,x="Year",y="Value",title="World GDP Analysis")
fig

# %%
pyo.plot(fig,filename='plot.html')
# Out:
# 'plot.html'

# %%
import os

# %%
os.mkdir("GDP plots1")
for i in df["Country Name"].unique():
    df3=df[df["Country Name"]=='India']
    fig=px.line(df3,x="Year",y="Value",title="World GDP Analysis")
    pyo.plot(fig,filename=i+'.html',auto_open=False)

# %%
fig=px.line(df,x="Year",y="Value",title="Gdp analysis of all countries",color="Country Name")
pyo.plot(fig,filename='gdp1.html')
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\plotly\express\_core.py:1979: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# 'gdp1.html'

# %%
fig=px.line(df,x="Year",y="GDP",title="Gdp analysis of all countries",color="Country Name")
pyo.plot(fig,filename='gdp2.html')
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\plotly\express\_core.py:1979: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# 'gdp2.html'

# %%
df.head()
# Out:
#   Country Name Country Code  Year         Value    GDP
# 0   Arab World          ARB  1968  2.576068e+10   0.00
# 1   Arab World          ARB  1969  2.843420e+10  10.38
# 2   Arab World          ARB  1970  3.138550e+10  10.38
# 3   Arab World          ARB  1971  3.642691e+10  16.06
# 4   Arab World          ARB  1972  4.331606e+10  18.91

# %%
df1=df[df["Country Name"]=='India']

# %%
df1["Year"].nunique()
# Out:
# 57

# %%
df3=df[df["Country Name"]=="World"]

# %%
df3[df3["Year"]==1969]
# Out:
#      Country Name Country Code  Year         Value    GDP
# 2258        World          WLD  1969  2.690798e+12  10.13

# %%
df1
# Out:
#      Country Name Country Code  Year         Value    GDP
# 6074        India          IND  1960  3.653593e+10   0.00
# 6075        India          IND  1961  3.870910e+10   5.95
# 6076        India          IND  1962  4.159907e+10   7.47
# 6077        India          IND  1963  4.777600e+10  14.85
# 6078        India          IND  1964  5.572687e+10  16.64
# 6079        India          IND  1965  5.876042e+10   5.44
# 6080        India          IND  1966  4.525364e+10 -22.99
# 6081        India          IND  1967  4.946617e+10   9.31
# 6082        India          IND  1968  5.237732e+10   5.89
# 6083        India          IND  1969  5.766833e+10  10.10
# 6084        India          IND  1970  6.158980e+10   6.80
# 6085        India          IND  1971  6.645256e+10   7.90
# 6086        India          IND  1972  7.050991e+10   6.11
# 6087        India          IND  1973  8.437454e+10  19.66
# 6088        India          IND  1974  9.819828e+10  16.38
# ...
